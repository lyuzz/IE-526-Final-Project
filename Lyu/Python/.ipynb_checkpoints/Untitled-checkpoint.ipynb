# %%
import pandas as pd

# %%
df = pd.read_csv("../Materials/customer_info.csv")

# %%
df.describe()
# Out:
#         Unnamed: 0           ID    type  lng                   \
# count  1000.000000  1000.000000  1000.0           1000.000000
# mean    500.500000   500.500000     2.0            116.382137
# std     288.819436   288.819436     0.0              0.153507
# min       1.000000     1.000000     2.0            116.100162
# 25%     250.750000   250.750000     2.0            116.261446
# 50%     500.500000   500.500000     2.0            116.372360
# 75%     750.250000   750.250000     2.0            116.505035
# max    1000.000000  1000.000000     2.0            116.705558
#
#        lat                   pack_total_weight  pack_total_volume  \
# count           1000.000000        1000.000000        1000.000000
# mean              39.931063           0.280268           0.668203
# std                0.117149           0.361635           1.102173
# min               39.693569           0.010000           0.012200
# 25%               39.842764           0.048000           0.149050
# ...
